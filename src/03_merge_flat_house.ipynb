# %%
import pandas as pd
import numpy as np

# %%
flats=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_Clean.csv')
house=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/independent-house_clean.csv')

# %%
flats.sample()
# Out:
#                       property_name property_type          society  price  \
# 1102  3 BHK Flat in Nirvana Country          flat  the close north   2.35
#
#       price_per_sqft    area  \
# 1102         11767.0  1997.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1102  Super Built up area 1997(185.53 sq.m.)Built Up...        3         3
#
#      balcony additionalRoom                                 address  floorNum  \
# 1102      3+  not available  8/9, Nirvana Country, Gurgaon, Haryana       8.0
#
#           facing     agePossession  \
# 1102  North-East  5 to 10 Year Old
#
#                                         nearbyLocations  \
# 1102  ['Sector 55-56 Metro Station', 'Eros City Squa...
#
#                                             description  \
# 1102  Situated in nirvana country, gurgaon, the clos...
#
#                                          furnishDetails  \
# 1102  ['5 Fan', '1 Exhaust Fan', '3 Geyser', '1 Stov...
#
# ...

# %%
house.sample()
# Out:
#                                        property_name property_type  \
# 820  3 Bedroom House for sale in Sushant Lok Phase 1         house
#
#                           society  price  price_per_sqft    area  \
# 820  sushant lok 1 builder floors   13.0         48148.0  2700.0
#
#                     areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 820  Plot area 300(250.84 sq.m.)        3         3      3+     pooja room
#
#                                    address  floorNum facing    agePossession  \
# 820  Sushant Lok Phase 1, Gurgaon, Haryana       4.0  North  0 to 1 Year Old
#
#                                        nearbyLocations  \
# 820  ['Huda city centre metro station', 'New Life C...
#
#                                            description  \
# 820  Sushant lok a block gated line . Floor wise bu...
#
#                                         furnishDetails             features  \
# ...

# %%
df=pd.concat([flats,house],ignore_index=True)

# %%
df.shape
# Out:
# (3960, 20)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.sample(5)
# Out:
#                                       property_name property_type  \
# 614            18 Bedroom House for sale in Suncity         house
# 1217               3 BHK Flat in Sector 63A Gurgaon          flat
# 1985               3 BHK Flat in Sector 102 Gurgaon          flat
# 3758  4 Bedroom House for sale in Sector 46 Gurgaon         house
# 375                4 BHK Flat in Sector 108 Gurgaon          flat
#
#                                    society  price  price_per_sqft    area  \
# 614                            independent   5.50         38194.0  1440.0
# 1217                           birla navya   3.30         15348.0  2150.0
# 1985  shapoorji pallonji joyville gurugram   2.00         17729.0  1128.0
# 3758                           independent   2.25         24510.0   918.0
# 375                             sobha city   4.10         23401.0  1752.0
#
#                                            areaWithType  bedRoom  bathroom  \
# ...

# %%
df.to_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_and_house.csv',index=False)
