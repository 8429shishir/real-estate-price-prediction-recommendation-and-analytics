# %%
import pandas as pd
import numpy as np

# %%
flats=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_Clean.csv')
house=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/independent-house_clean.csv')

# %%
flats.sample()
# Out:
#                         property_name property_type  \
# 1067  4 BHK Flat in Sector 65 Gurgaon          flat
#
#                                society  price  price_per_sqft    area  \
# 1067  emaar mgf emerald floors premier    2.8         16969.0  1650.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1067  Super Built up area 1975(183.48 sq.m.)Built Up...        4         4
#
#      balcony additionalRoom                                   address  \
# 1067       3     study room  101, Sector 65 Gurgaon, Gurgaon, Haryana
#
#       floorNum facing    agePossession  \
# 1067       2.0  North  1 to 5 Year Old
#
#                                         nearbyLocations  \
# 1067  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
#
#                                             description  \
# 1067  This lovely 4 bhk apartment/flat in sector 65 ...
#
#                                          furnishDetails  \
# 1067  ['4 Wardrobe', '6 Fan', '1 Exhaust Fan', '5 Ge...
#
#                                                features  \
# 1067  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 1067  ['Green Area4.5 out of 5', 'Construction5 out ...

# %%
house.sample()
# Out:
#                              property_name property_type      society  price  \
# 139  6 Bedroom House for sale in Madanpuri         house  independent    0.9
#
#      price_per_sqft   area                areaWithType  bedRoom  bathroom  \
# 139         10000.0  900.0  Plot area 100(83.61 sq.m.)        6         4
#
#     balcony       additionalRoom                      address  floorNum  \
# 139       3  servant room,others  Madanpuri, Gurgaon, Haryana       3.0
#
#          facing agePossession  \
# 139  North-East  10+ Year Old
#
#                                        nearbyLocations  \
# 139  ['Dev Man Kathuria Clinic', 'Dr. Madan Clinic'...
#
#                                            description  \
# 139  Corner property, two side open, 30 by 30 with ...
#
#                                         furnishDetails  \
# 139  ['5 Fan', '1 Exhaust Fan', '1 Geyser', '6 Ligh...
#
#                                               features  \
# 139  ['Feng Shui / Vaastu Compliant', 'Water Storag...
#
#                                                 rating
# 139  ['Environment4 out of 5', 'Lifestyle4 out of 5...

# %%
df=pd.concat([flats,house],ignore_index=True)

# %%
df.shape
# Out:
# (3960, 20)

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df.sample(5)
# Out:
#                          property_name property_type                  society  \
# 1314   3 BHK Flat in Sector 77 Gurgaon          flat     emaar mgf palm hills
# 589   3 BHK Flat in Sector 103 Gurgaon          flat  indiabulls centrum park
# 2307   3 BHK Flat in Sector 67 Gurgaon          flat               m3m merlin
# 2681  3 BHK Flat in Sector 107 Gurgaon          flat            m3m woodshire
# 3410  3 BHK Flat in Sector 37C Gurgaon          flat             corona optus
#
#       price  price_per_sqft    area  \
# 1314   1.90          9500.0  2000.0
# 589    1.34          7882.0  1700.0
# 2307   2.65         12945.0  2047.0
# 2681   1.30          8922.0  1457.0
# 3410   1.25          7090.0  1763.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1314  Super Built up area 2000(185.81 sq.m.)Carpet a...        3         4
# 589   Super Built up area 1725(160.26 sq.m.)Carpet a...        3         3
# 2307  Super Built up area 2047(190.17 sq.m.)Built Up...        3         3
# 2681  Super Built up area 1943(180.51 sq.m.)Built Up...        3         3
# 3410  Super Built up area 1763(163.79 sq.m.)Built Up...        3         3
#
#      balcony                                 additionalRoom  \
# 1314      3+                                   servant room
# 589       3+  pooja room,study room,servant room,store room
# 2307       3                                         others
# 2681      3+                                     pooja room
# 3410       3                                         others
#
#                                                 address  floorNum      facing  \
# 1314                Sector 77 Gurgaon, Gurgaon, Haryana       6.0  South-West
# 589        154562, Sector 103 Gurgaon, Gurgaon, Haryana      12.0        East
# 2307           101, Sector 67 Gurgaon, Gurgaon, Haryana       NaN  North-East
# 2681  Dwarka Expressway, Sector 107 Gurgaon, Gurgaon...       4.0        West
# 3410       T1-101, Sector 37C Gurgaon, Gurgaon, Haryana       4.0  North-West
#
#         agePossession                                    nearbyLocations  \
# 1314  0 to 1 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Soh...
# 589   1 to 5 Year Old  ['Gurgaon Dreamz Mall', 'HUDA Market, Sector 1...
# 2307  1 to 5 Year Old  ['Airia Mall', 'Golf Course Extension Road', '...
# 2681  1 to 5 Year Old  ['Signum 107', 'Nora Solomon Medicenter', 'Ind...
# 3410  1 to 5 Year Old  ['The Esplanade Mall', 'Gurugram Road', 'Delhi...
#
#                                             description  \
# 1314  Ready to move in property with wardrobes, fans...
# 589   This lovely 3 bhk apartment/flat in sector 103...
# 2307  This lovely 3 bhk apartment/flat in sector 67 ...
# 2681  Available 3 bhk spacious apartment at best pri...
# 3410  Optus corona is a ready to move residential pr...
#
#                                          furnishDetails  \
# 1314  ['4 Wardrobe', '7 Fan', '1 Exhaust Fan', '4 Ge...
# 589   ['9 Fan', '9 Light', '4 AC', '1 Modular Kitche...
# 2307  ['6 Fan', '1 Exhaust Fan', '4 Geyser', '1 Stov...
# 2681  ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '1 Ge...
# 3410                                                NaN
#
#                                                features  \
# 1314  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 589   ['Lift(s)', 'Swimming Pool', 'Park', 'Shopping...
# 2307  ['Centrally Air Conditioned', 'Water purifier'...
# 2681  ['Centrally Air Conditioned', 'Water purifier'...
# 3410  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
#                                                  rating
# 1314  ['Green Area4 out of 5', 'Construction4.5 out ...
# 589   ['Green Area5 out of 5', 'Construction4 out of...
# 2307  ['Green Area4 out of 5', 'Construction4 out of...
# 2681  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3410  ['Green Area5 out of 5', 'Construction4 out of...

# %%
df.to_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_and_house.csv')
