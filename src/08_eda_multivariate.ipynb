# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_and_house_v2.csv').drop_duplicates()

# %%
df.head(5)
# Out:
#   property_type               society      sector  price  price_per_sqft  \
# 0         house           independent    sector 4   0.58         86567.0
# 1          flat  emaar mgf palm hills   sector 77   1.25          8620.0
# 2          flat            chd avenue   sector 71   1.00          6734.0
# 3          flat             ild grand  sector 37c   1.20          6593.0
# 4          flat        dlf the ultima   sector 81   2.20         10461.0
#
#      area                                       areaWithType  bedRoom  \
# 0    67.0                           Plot area 67(6.22 sq.m.)        2
# 1  1450.0  Super Built up area 1450(134.71 sq.m.)Carpet a...        3
# 2  1485.0             Super Built up area 1485(137.96 sq.m.)        3
# 3  1820.0             Super Built up area 1820(169.08 sq.m.)        3
# 4  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum facing       agePossession  super_built_up_area  \
# 0         2       1       2.0   West      Moderately Old                  NaN
# 1         4       3       3.0  North      Relatively New               1450.0
# 2         3      3+       3.0  North      Relatively New               1485.0
# 3         3       3       7.0    NaN  Under Construction               1820.0
# 4         3      3+       5.0   East      Relatively New               2103.0
#
#    built_up_area  carpet_area  study room  servant room  store room  \
# 0           67.0          NaN           0             0           0
# 1            NaN       1177.0           1             1           0
# 2            NaN          NaN           0             0           0
# 3            NaN          NaN           0             0           0
# 4         1570.0       1257.0           1             1           0
#
#    pooja room  others  furnishing_type  luxury_score
# 0           1       1                1             7
# 1           0       0                1            49
# 2           0       0                2             7
# 3           0       0                1            24
# 4           1       1                0            49

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %%
sns.boxplot(x=df['property_type'],y=df['price'])
# Out:
# <Axes: xlabel='property_type', ylabel='price'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'],y=df['built_up_area'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'],y=df['price_per_sqft'],estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society     sector  price  \
# 70           house                   ardee city  sector 52   5.50
# 82           house                  independent  sector 38   8.00
# 693          house         bhim nagar, sector 6   sector 6   0.85
# 827          house                dlf the grove  sector 54   5.70
# 1039         house            vatika india next  sector 82   7.00
# 1083         house     unitech uniworld resorts  sector 33  10.00
# 1090         house                  independent   sector 4   0.60
# 1173          flat           ambience caitriona  sector 24  14.00
# 1334         house                  independent  sector 24  10.00
# 1445         house                  independent  sector 12   6.00
# 1478         house       dlf city plots phase 2  sector 25  10.00
# 1539         house                  independent  sector 12   3.50
# 1572         house                  independent  sector 54   3.75
# 1652         house       dlf city plots phase 2  sector 25  10.50
# 1692         house       emaar the palm springs  sector 54  24.00
# 1814         house                    rk excelo  sector 12   0.60
# 1877         house                        ansal  sector 43   1.85
# 2012         house          huda plot sector 38  sector 38   4.30
# 2114         house                  independent  sector 57   8.00
# 2148         house                  independent  sector 55   1.45
# 2158         house                  independent  sector 28   4.50
# 2203         house  unitech nirvana birch court  sector 50   7.10
# 2311         house           vipul tatvam villa  sector 48   7.25
# 2580         house     unitech uniworld resorts  sector 33   9.50
# 2661         house                  independent  sector 17   3.50
# 2793         house               uppal southend  sector 49   6.75
# 3367         house       unitech deerwood chase  sector 50   8.45
# 3451         house                  independent  sector 23   2.80
# 3755         house         eros rosewood villas  sector 49   2.75
#
#       price_per_sqft   area  \
# 70          183333.0  300.0
# 82          230547.0  347.0
# 693         126865.0   67.0
# 827         211111.0  270.0
# 1039        194444.0  360.0
# 1083        181818.0  550.0
# 1090        105263.0   57.0
# 1173        200000.0  700.0
# 1334        229885.0  435.0
# 1445        315789.0  190.0
# 1478        400000.0  250.0
# 1539        133079.0  263.0
# 1572        234375.0  160.0
# 1652        261194.0  402.0
# 1692        600000.0  400.0
# 1814        120000.0   50.0
# 1877        308333.0   60.0
# 2012        245398.0  175.0
# 2114        266666.0  300.0
# 2148        241666.0   60.0
# 2158        125000.0  360.0
# 2203        283333.0  251.0
# 2311        201388.0  360.0
# 2580        173992.0  546.0
# 2661        218750.0  160.0
# 2793        290948.0  232.0
# 3367        235376.0  359.0
# 3451        161849.0  173.0
# 3755        178571.0  154.0
#
#                                            areaWithType  super_built_up_area  \
# 70                           Plot area 300(27.87 sq.m.)                  NaN
# 82    Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 693                            Plot area 67(6.22 sq.m.)                  NaN
# 827                    Built Up area: 270 (25.08 sq.m.)                  NaN
# 1039  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 1083                          Plot area 550(51.1 sq.m.)                  NaN
# 1090                            Plot area 57(5.3 sq.m.)                  NaN
# 1173                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1334                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 1445  Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 1478                         Plot area 250(23.23 sq.m.)                  NaN
# 1539  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 1572                         Plot area 160(14.86 sq.m.)                  NaN
# 1652                         Plot area 402(37.35 sq.m.)                  NaN
# 1692                         Plot area 400(37.16 sq.m.)                  NaN
# 1814  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 1877                           Plot area 60(5.57 sq.m.)                  NaN
# 2012  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 2114                         Plot area 300(27.87 sq.m.)                  NaN
# 2148                           Plot area 60(5.57 sq.m.)                  NaN
# 2158                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2203                          Plot area 240(22.3 sq.m.)                  NaN
# 2311                         Plot area 360(33.45 sq.m.)                  NaN
# 2580                         Plot area 546(50.73 sq.m.)                  NaN
# 2661                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 2793                         Plot area 232(21.55 sq.m.)                  NaN
# 3367                         Plot area 359(33.35 sq.m.)                  NaN
# 3451  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3755  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
#
#       built_up_area  carpet_area
# 70            300.0          NaN
# 82            347.0        215.0
# 693            67.0          NaN
# 827           270.0          NaN
# 1039         3900.0       3743.0
# 1083          550.0          NaN
# 1090           57.0          NaN
# 1173          700.0          NaN
# 1334            NaN        435.0
# 1445            NaN       1600.0
# 1478          250.0          NaN
# 1539         4800.0       4400.0
# 1572          160.0          NaN
# 1652          402.0          NaN
# 1692          400.0          NaN
# 1814           30.0         15.0
# 1877           60.0          NaN
# 2012          145.0          NaN
# 2114          300.0          NaN
# 2148           60.0          NaN
# 2158          360.0          NaN
# 2203          240.0          NaN
# 2311          360.0          NaN
# 2580          546.0          NaN
# 2661          160.0          NaN
# 2793          232.0          NaN
# 3367          359.0          NaN
# 3451          160.0        150.0
# 3755            NaN       1650.0

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
df[df['bedRoom']>=10]
# Out:
#      property_type           society           sector  price  price_per_sqft  \
# 82           house       independent        sector 38   8.00        230547.0
# 163          house       independent        sector 11   4.50         25000.0
# 362          house       independent        sector 55   9.19         34037.0
# 380          house       independent  sohna road road   0.95          8920.0
# 443          house       independent        sector 46   6.81         36911.0
# ...            ...               ...              ...    ...             ...
# 3257         house       independent        sector 56  11.95         43534.0
# 3263         house       independent        sector 26   8.49         47167.0
# 3401         house       independent        sector 43   3.00         53763.0
# 3470         house       independent        sector 43   2.10         38251.0
# 3732         house  dlf city phase 1        sector 26   9.25         47803.0
#
#         area                                       areaWithType  bedRoom  \
# 82     347.0  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...       10
# 163   1800.0                        Plot area 200(167.23 sq.m.)       16
# 362   2700.0                        Plot area 300(250.84 sq.m.)       16
# 380   1065.0                        Plot area 1065(98.94 sq.m.)       10
# 443   1845.0                        Plot area 205(171.41 sq.m.)       12
# ...      ...                                                ...      ...
# 3257  2745.0                        Plot area 305(255.02 sq.m.)       12
# 3263  1800.0                        Plot area 200(167.23 sq.m.)       12
# 3401   558.0                          Plot area 62(51.84 sq.m.)       12
# 3470   549.0                             Plot area 61(51 sq.m.)       10
# 3732  1935.0  Plot area 1935(179.77 sq.m.)Built Up area: 700...       12
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 82          10      3+       1.0       North       Undefined
# 163         16      3+       4.0       South  Relatively New
# 362         18       2       4.0        West    New Property
# 380         10      3+       3.0         NaN    New Property
# 443         14      3+       NaN        East    New Property
# ...        ...     ...       ...         ...             ...
# 3257        12      3+       4.0        West  Relatively New
# 3263        12      3+       4.0       North  Relatively New
# 3401        12      3+       5.0        West    New Property
# 3470        10      3+       5.0        West    New Property
# 3732        12      3+       4.0  North-East    New Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 82                    NaN          347.0        215.0           0
# 163                   NaN         1800.0          NaN           0
# 362                   NaN         2700.0          NaN           0
# 380                   NaN         1065.0          NaN           0
# 443                   NaN         1845.0          NaN           0
# ...                   ...            ...          ...         ...
# 3257                  NaN         2745.0          NaN           0
# 3263                  NaN         1800.0          NaN           0
# 3401                  NaN          558.0          NaN           0
# 3470                  NaN          549.0          NaN           0
# 3732                  NaN         7000.0          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 82               0           0           0       0                1
# 163              0           0           0       0                2
# 362              1           0           1       0                2
# 380              0           0           0       0                1
# 443              1           0           0       1                2
# ...            ...         ...         ...     ...              ...
# 3257             1           0           0       0                2
# 3263             1           0           1       0                2
# 3401             0           0           0       1                0
# 3470             1           0           0       0                1
# 3732             1           0           1       0                2
#
#       luxury_score
# 82               0
# 163             20
# 362             49
# 380              0
# 443             40
# ...            ...
# 3257            21
# 3263            42
# 3401            20
# 3470            20
# 3732            43
#
# [72 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society      sector  price  \
# 127          house      ireo victory valley   sector 67   8.00
# 161          house               ninex city   sector 76   1.75
# 803          house              greenopolis   sector 89   0.70
# 869          house              spaze privy   sector 72   3.09
# 1407         house   vatika the seven lamps   sector 82   1.60
# 1809         house  indiabulls centrum park  sector 103   3.25
# 1977         house        suncity avenue 76   sector 76   0.75
# 2124         house           dlf the arbour   sector 63   8.50
# 2156         house      satya the hermitage  sector 103   3.15
# 2228         house         suncity township   sector 54   2.00
# 2662         house           ats tourmaline  sector 109   1.87
# 2986         house          godrej meridien  sector 106   5.60
# 3006         house              independent   sector 92   1.80
# 3752         house              spaze privy   sector 72   3.10
#
#       price_per_sqft    area  \
# 127          22222.0  3600.0
# 161           6250.0  2800.0
# 803           5397.0  1297.0
# 869           6981.0  4426.0
# 1407          6597.0  2425.0
# 1809          8125.0  4000.0
# 1977         10067.0   745.0
# 2124         21519.0  3950.0
# 2156          6702.0  4700.0
# 2228         30968.0   646.0
# 2662          8697.0  2150.0
# 2986         14000.0  4000.0
# 3006          7627.0  2360.0
# 3752          8486.0  3653.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 127                         Plot area 400(334.45 sq.m.)        6         7
# 161                    Carpet area: 2800 (260.13 sq.m.)        4         4
# 803                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 869   Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 1407                       Plot area 2425(225.29 sq.m.)        4         4
# 1809                       Plot area 4000(371.61 sq.m.)        4         3
# 1977  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 2124                 Built Up area: 3950 (366.97 sq.m.)        4         4
# 2156                 Built Up area: 4700 (436.64 sq.m.)        4         5
# 2228  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 2662                 Built Up area: 2150 (199.74 sq.m.)        3         4
# 2986                       Plot area 4000(371.61 sq.m.)        5         4
# 3006                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 3752                       Plot area 3653(339.37 sq.m.)        5         5
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 127       3+      51.0  North-East  Moderately Old                  NaN
# 161        0      14.0         NaN       Undefined                  NaN
# 803        2      14.0  North-East       Undefined                  NaN
# 869       3+      14.0        East  Relatively New                  NaN
# 1407      3+      16.0       North  Moderately Old                  NaN
# 1809      3+      20.0         NaN       Undefined                  NaN
# 1977       2      11.0  North-East    New Property                  NaN
# 2124      3+      27.0         NaN       Undefined                  NaN
# 2156       0      12.0        East       Undefined                  NaN
# 2228       3      11.0       North  Relatively New                  NaN
# 2662       0      12.0         NaN       Undefined                  NaN
# 2986      3+      33.0  North-East    New Property                  NaN
# 3006       0      13.0         NaN       Undefined                  NaN
# 3752      3+      21.0         NaN  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 127          3600.0          NaN           1             1           0
# 161             NaN       2800.0           0             0           0
# 803          1297.0          NaN           0             0           0
# 869          3653.0       2922.0           0             1           0
# 1407         2425.0          NaN           0             1           0
# 1809         4000.0          NaN           0             0           0
# 1977          745.0          NaN           0             0           0
# 2124         3950.0          NaN           0             0           0
# 2156         4700.0          NaN           0             0           0
# 2228           60.0         59.0           0             1           0
# 2662         2150.0          NaN           0             0           0
# 2986         4000.0          NaN           1             1           1
# 3006         2360.0          NaN           0             0           0
# 3752         3653.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 127            1       0                2            49
# 161            0       0                1             0
# 803            0       0                1             0
# 869            0       0                2            33
# 1407           0       0                1            94
# 1809           0       0                1            51
# 1977           0       0                1            40
# 2124           0       0                1            61
# 2156           0       0                1            61
# 2228           0       0                0             7
# 2662           0       0                1             0
# 2986           1       0                1           151
# 3006           0       0                1             0
# 3752           0       0                1             0

# %% [markdown]
# houses but in the appartment

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean')
# Out:
# agePossession  Moderately Old  New Property  Old Property  Relatively New  \
# property_type
# flat                 2.102196      1.540412      1.881870        1.682962
# house                5.640905      6.279423      4.778715        6.634577
#
# agePossession  Undefined  Under Construction
# property_type
# flat            1.567151            1.726443
# house           2.573955            3.337500

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,6))
sns.heatmap(pd.pivot_table(
    df,
    index='property_type',
    columns='bedRoom',
    values='price',
    aggfunc='mean'
),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
pd.crosstab(df['property_type'],df['furnishing_type'])
# Out:
# furnishing_type    0     1    2
# property_type
# flat             144  1932  741
# house             58   504  297

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'],estimator=np.mean)
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['bedRoom'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df[df['area']<10000]['area'],y=df['price'],hue=df['agePossession'])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price'>

# %%
sns.barplot(x=df['agePossession'],y=df['price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['luxury_score'],y=df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %% [markdown]
# ## correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['price'].sort_values(ascending=False)
# Out:
# price                  1.000000
# super_built_up_area    0.769412
# bathroom               0.589826
# built_up_area          0.551649
# bedRoom                0.522925
# servant room           0.400927
# price_per_sqft         0.391251
# pooja room             0.341492
# store room             0.309121
# study room             0.258602
# furnishing_type        0.133418
# luxury_score           0.094775
# area                   0.034720
# others                -0.003525
# carpet_area           -0.011344
# floorNum              -0.110026
# Name: price, dtype: float64

# %%
sns.pairplot(df)
