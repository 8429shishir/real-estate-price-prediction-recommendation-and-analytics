# %%
# !pip uninstall pandas-profiling
# !pip install ydata-profiling
# Out:
# ^C
# Requirement already satisfied: ydata-profiling in e:\mtech projects\virtual environment\venv\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (2.13.2)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (2.2.6)
# Requirement already satisfied: minify-html>=0.15.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in e:\mtech projects\virtual environment\venv\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in e:\mtech projects\virtual environment\venv\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in e:\mtech projects\virtual environment\venv\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\mtech projects\virtual environment\venv\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.2)
# Requirement already satisfied: typing-extensions>=4.14.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\mtech projects\virtual environment\venv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\mtech projects\virtual environment\venv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in e:\mtech projects\virtual environment\venv\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.1.4)
# Requirement already satisfied: patsy>=0.5.6 in e:\mtech projects\virtual environment\venv\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in e:\mtech projects\virtual environment\venv\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in e:\mtech projects\virtual environment\venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in e:\mtech projects\virtual environment\venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Requirement already satisfied: puremagic in e:\mtech projects\virtual environment\venv\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: six>=1.5 in e:\mtech projects\virtual environment\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
# C:\Users\8429s\AppData\Local\Temp\ipykernel_15696\2829373970.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
# Load your dataset
df=pd.read_csv('C:/Users/8429s/OneDrive/Desktop/Placement/Projects/Real Estate Price Prediction and Recommendation System/Data_Clean/flats_and_house_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 23/23 [00:00<00:00, 570.14it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
